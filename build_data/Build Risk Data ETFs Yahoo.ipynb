# %%
import pandas as pd
import numpy as np

import yfinance as yf
# Out:
# /Users/markhendricks/Projects/finm-portfolio-2023/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
TICKS = [
    'SPY',
    'VEA',
    'UPRO',
    'GLD',
    'USO',
    'FXE',
    'BTC-USD',
    'HYG',
    'IEF',
    'TIP',
    'SHV',
]

FLDS = ['quoteType','shortName','volume','totalAssets','longBusinessSummary']

# %%
info = pd.DataFrame(index=TICKS,columns=FLDS)
info.index.name = 'ticker'
for tick in info.index:
    temp = yf.Ticker(tick).get_info()

    for fld in FLDS:
        if fld in temp.keys():
            info.loc[tick,fld] = temp[fld]

# %%
prices = yf.download(TICKS, start="2017-01-01", end="2023-09-30")['Adj Close'][info.index]
prices.rename(columns={'BTC-USD':'BTC', 'CL=F':'CL1'},inplace=True)
prices.dropna(inplace=True)
rets = prices.pct_change().dropna()
# Out:
# [*********************100%%**********************]  11 of 11 completed

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500    113156018
# VEA                 ETF  Vanguard FTSE Developed Markets     11812798
# UPRO                ETF       ProShares UltraPro S&P 500      9894668
# GLD                 ETF                  SPDR Gold Trust      9867507
# USO                 ETF           United States Oil Fund      3869036
# FXE                 ETF  Invesco CurrencyShares Euro Cur       324673
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  13161085952
# HYG                 ETF  iShares iBoxx $ High Yield Corp     52371903
# IEF                 ETF  iShares 7-10 Year Treasury Bond     12247240
# TIP                 ETF            iShares TIPS Bond ETF      2160708
# SHV                 ETF  iShares Short Treasury Bond ETF      3298708
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      400955080704  The Trust seeks to achieve its investment obje...
# VEA      160824967168  The fund employs an indexing investment approa...
# UPRO       2405910272  The fund invests in financial instruments that...
# GLD       52521267200  The Trust holds gold bars and from time to tim...
# USO        1479587072  USO invests primarily in futures contracts for...
# FXE         229981776                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       13917031424  The underlying index is a rules-based index co...
# IEF       27455670272  The underlying index measures the performance ...
# TIP       20525127680  The index tracks the performance of inflation-...
# SHV       20322351104  The fund will invest at least 80% of its asset...

# %%
rets
# Out:
#                  SPY       VEA      UPRO       GLD       USO       FXE  \
# Date
# 2017-01-04  0.005949  0.012238  0.017834  0.003530  0.012238  0.009313
# 2017-01-05 -0.000794  0.008866 -0.003057  0.015515  0.010363  0.010896
# 2017-01-06  0.003578 -0.003995  0.011323 -0.007373 -0.001709 -0.006700
# 2017-01-09 -0.003301 -0.002406 -0.009447  0.008233 -0.031678  0.003617
# 2017-01-10  0.000000  0.001072 -0.001648  0.004260 -0.021220 -0.001071
# ...              ...       ...       ...       ...       ...       ...
# 2023-09-25  0.004205 -0.003829  0.013049 -0.005151 -0.002977 -0.004171
# 2023-09-26 -0.014691 -0.014244 -0.045199 -0.007991  0.006095 -0.002145
# 2023-09-27  0.000399 -0.002294  0.001717 -0.012367  0.024975 -0.006143
# 2023-09-28  0.005797  0.008276  0.016161 -0.004997 -0.016043  0.005563
# 2023-09-29 -0.002427 -0.003192 -0.007952 -0.010275 -0.008704  0.000922
#
#                  BTC       HYG       IEF       TIP       SHV
# Date
# 2017-01-04  0.106233  0.005408  0.001145  0.002207 -0.000091
# 2017-01-05 -0.122410 -0.001488  0.006483  0.003435 -0.000091
# 2017-01-06 -0.109711 -0.000228 -0.004546 -0.004126  0.000272
# 2017-01-09  0.000695 -0.000230  0.003806  0.001587  0.000181
# 2017-01-10  0.005373  0.000115 -0.000474  0.000792 -0.000091
# ...              ...       ...       ...       ...       ...
# 2023-09-25 -0.010575 -0.001351 -0.007356 -0.007551  0.000091
# 2023-09-26 -0.003089 -0.004330 -0.000327 -0.002504  0.000091
# 2023-09-27  0.005167 -0.001359 -0.004470 -0.001641  0.000181
# 2023-09-28  0.025380  0.004763  0.002738  0.005126  0.000453
# 2023-09-29 -0.004064 -0.001490  0.000218 -0.002021  0.000000
#
# [1696 rows x 11 columns]

# %%
with pd.ExcelWriter('../data/risk_etf_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    rets.to_excel(writer, sheet_name='total returns')
    prices.to_excel(writer, sheet_name='prices')

# %%
info
# Out:
#               quoteType                        shortName       volume  \
# ticker
# SPY                 ETF                     SPDR S&P 500    113156018
# VEA                 ETF  Vanguard FTSE Developed Markets     11812798
# UPRO                ETF       ProShares UltraPro S&P 500      9894668
# GLD                 ETF                  SPDR Gold Trust      9867507
# USO                 ETF           United States Oil Fund      3869036
# FXE                 ETF  Invesco CurrencyShares Euro Cur       324673
# BTC-USD  CRYPTOCURRENCY                      Bitcoin USD  13161085952
# HYG                 ETF  iShares iBoxx $ High Yield Corp     52371903
# IEF                 ETF  iShares 7-10 Year Treasury Bond     12247240
# TIP                 ETF            iShares TIPS Bond ETF      2160708
# SHV                 ETF  iShares Short Treasury Bond ETF      3298708
#
#           totalAssets                                longBusinessSummary
# ticker
# SPY      400955080704  The Trust seeks to achieve its investment obje...
# VEA      160824967168  The fund employs an indexing investment approa...
# UPRO       2405910272  The fund invests in financial instruments that...
# GLD       52521267200  The Trust holds gold bars and from time to tim...
# USO        1479587072  USO invests primarily in futures contracts for...
# FXE         229981776                                                NaN
# BTC-USD           NaN                                                NaN
# HYG       13917031424  The underlying index is a rules-based index co...
# IEF       27455670272  The underlying index measures the performance ...
# TIP       20525127680  The index tracks the performance of inflation-...
# SHV       20322351104  The fund will invest at least 80% of its asset...
